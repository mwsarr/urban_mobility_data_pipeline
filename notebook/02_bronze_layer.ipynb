# %%
# %run "./01_ingestion"

# %%
calendar_df.write.format("delta").mode("overwrite").saveAsTable("calendar")

# %%
yellow_taxi_trip_df.write.format("delta").mode("overwrite").saveAsTable("yellow_taxi_trip_bronze")

# %%
taxi_zone_df.write.format("delta").mode("overwrite").saveAsTable("taxi_zone_bronze")

# %%
weather_df.write.format("delta").mode("overwrite").saveAsTable("weather_bronze")
